# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
import joblib

# %%
df = pd.read_csv('../industry_exposure.csv', skipinitialspace=True)
x_cols = [c for c in df.columns if c != 'industry']
X = df[x_cols]
y = df['industry']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)
print(f"Train: {X_train.shape}, Test: {X_test.shape}")
# Out:
# Train: (175, 14), Test: (75, 14)

# %%
train_mode = dict(X_train.mode().iloc[0])
X_train = X_train.fillna(train_mode)
print("Fill values:", train_mode)
# Out:
# Fill values: {'year': np.float64(2003.0), 'pandemic_exposure': np.float64(6.1), 'geopolitical_exposure': np.float64(9.1), 'natural_disaster_exposure': np.float64(4.9), 'tariff_exposure': np.float64(7.2), 'logistics_exposure': np.float64(6.9), 'energy_exposure': np.float64(6.1), 'labor_exposure': np.float64(7.0), 'cyber_exposure': np.float64(7.0), 'overall_vulnerability': np.float64(6.3), 'inventory_days': np.float64(22.0), 'supplier_concentration_hhi': np.float64(0.161), 'just_in_time_dependency': np.float64(0.424), 'nearshoring_score_2024': np.float64(0.43)}

# %%
rf = RandomForestClassifier(n_estimators=100)
rf = rf.fit(X_train, y_train)

et = ExtraTreesClassifier(n_estimators=100)
et = et.fit(X_train, y_train)
print("Models trained!")
# Out:
# Models trained!

# %%
joblib.dump(train_mode, "./train_mode.joblib", compress=True)
joblib.dump(rf, "./random_forest.joblib", compress=True)
joblib.dump(et, "./extra_trees.joblib", compress=True)
print("All 3 files saved to research/ directory!")
# Out:
# All 3 files saved to research/ directory!
